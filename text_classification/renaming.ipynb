# %%
import pandas as pd
import os
output_dir = 'data_v2/neutral'

index = 1
for filename in os.listdir(output_dir):
    old_file_path = os.path.join(output_dir, filename)
    
    if os.path.isfile(old_file_path):
        new_filename = f"neutral_{index}.txt"
        new_file_path = os.path.join(output_dir, new_filename)
        os.rename(old_file_path, new_file_path)
        print(f"Renamed: {filename} to {new_filename}")
        
        index += 1
# Out:
# Renamed: commands_100.txt to neutral_1.txt
# Renamed: commands_85.txt to neutral_2.txt
# Renamed: commands_90.txt to neutral_3.txt
# Renamed: commands_84.txt to neutral_4.txt
# Renamed: commands_53.txt to neutral_5.txt
# Renamed: commands_47.txt to neutral_6.txt
# Renamed: commands_115.txt to neutral_7.txt
# Renamed: commands_101.txt to neutral_8.txt
# Renamed: commands_129.txt to neutral_9.txt
# Renamed: commands_79.txt to neutral_10.txt
# Renamed: commands_92.txt to neutral_11.txt
# Renamed: commands_8.txt to neutral_12.txt
# Renamed: commands_87.txt to neutral_13.txt
# Renamed: commands_78.txt to neutral_14.txt
# Renamed: commands_44.txt to neutral_15.txt
# Renamed: commands_50.txt to neutral_16.txt
# Renamed: commands_248.txt to neutral_17.txt
# Renamed: commands_54.txt to neutral_18.txt
# Renamed: commands_41.txt to neutral_19.txt
# Renamed: commands_69.txt to neutral_20.txt
# Renamed: commands_107.txt to neutral_21.txt
# Renamed: commands_113.txt to neutral_22.txt
# ...

# %%
import os
import shutil

def copy_files(src_dir, dest_dir):
    # Ensure the source directory exists
    if not os.path.exists(src_dir):
        print(f"The source directory {src_dir} does not exist.")
        return
    
    # Ensure the destination directory exists, create it if not
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Loop through all files in the source directory
    for filename in os.listdir(src_dir):
        src_file_path = os.path.join(src_dir, filename)

        # Only copy if it is a file
        if os.path.isfile(src_file_path):
            dest_file_path = os.path.join(dest_dir, filename)

            # Copy the file
            shutil.copy(src_file_path, dest_file_path)
            print(f"Copied: {filename} to {dest_dir}")

# Example usage
src_dir = 'data_v1/keys'
dest_dir = 'data_v3/commands'
copy_files(src_dir, dest_dir)
# Out:
# Copied: keys_8.txt to data_v3/commands
# Copied: keys_19.txt to data_v3/commands
# Copied: keys_25.txt to data_v3/commands
# Copied: keys_24.txt to data_v3/commands
# Copied: keys_18.txt to data_v3/commands
# Copied: keys_9.txt to data_v3/commands
# Copied: keys_26.txt to data_v3/commands
# Copied: keys_27.txt to data_v3/commands
# Copied: keys_23.txt to data_v3/commands
# Copied: keys_22.txt to data_v3/commands
# Copied: keys_20.txt to data_v3/commands
# Copied: keys_21.txt to data_v3/commands
# Copied: keys_1.txt to data_v3/commands
# Copied: keys_10.txt to data_v3/commands
# Copied: keys_11.txt to data_v3/commands
# Copied: keys_2.txt to data_v3/commands
# Copied: keys_13.txt to data_v3/commands
# Copied: keys_12.txt to data_v3/commands
# Copied: keys_3.txt to data_v3/commands
# Copied: keys_7.txt to data_v3/commands
# Copied: keys_16.txt to data_v3/commands
# Copied: keys_17.txt to data_v3/commands
# Copied: keys_6.txt to data_v3/commands
# Copied: keys_4.txt to data_v3/commands
# ...
